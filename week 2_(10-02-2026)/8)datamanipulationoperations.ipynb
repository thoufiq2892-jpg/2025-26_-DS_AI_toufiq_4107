# %% [markdown]
# <a href="https://colab.research.google.com/github/thoufiq2892-jpg/2025-26_-DS_AI_toufiq_4107/blob/main/week%202_(10-02-2026)/8)datamanipulationoperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DATA MANIPULATION OPERATIONS
import pandas as pd
data={
    'Name':['A','B','C'],
    'Age':[20,21,22],
    'Marks':[70,80,90]
}
df=pd.DataFrame(data)
print("Original data:")
print(df)
#Adding a new column
df['Bonus']=5
print("After adding bonus:")
print(df)
#increasing marks
df['Marks']=df['Marks']+2
print("\nAfter increasing marks:")
print(df)
#create new column from existing columns
df["Total"]=df["Marks"]+df["Bonus"]
print("\nAfter adding total:")
print(df)
#change values
df.loc[1,"Age"]=23
print("\nAfter changing age:")
print(df)
#renaming column
df.rename(columns={"Total":"Final"},inplace=True)
print("\nAfter renaming:")
print(df)
#removing a column
df.drop("Bonus",axis=1,inplace=True)
print("\nAfter removing bonus:")
print(df)
# Out:
# Original data:
#   Name  Age  Marks
# 0    A   20     70
# 1    B   21     80
# 2    C   22     90
# After adding bonus:
#   Name  Age  Marks  Bonus
# 0    A   20     70      5
# 1    B   21     80      5
# 2    C   22     90      5
#
# After increasing marks:
#   Name  Age  Marks  Bonus
# 0    A   20     72      5
# 1    B   21     82      5
# 2    C   22     92      5
#
# After adding total:
#   Name  Age  Marks  Bonus  Total
# 0    A   20     72      5     77
# 1    B   21     82      5     87
# 2    C   22     92      5     97
#
# After changing age:
#   Name  Age  Marks  Bonus  Total
# 0    A   20     72      5     77
# 1    B   23     82      5     87
# 2    C   22     92      5     97
#
# After renaming:
#   Name  Age  Marks  Bonus  Final
# 0    A   20     72      5     77
# 1    B   23     82      5     87
# 2    C   22     92      5     97
#
# After removing bonus:
#   Name  Age  Marks  Final
# 0    A   20     72     77
# 1    B   23     82     87
# ...
